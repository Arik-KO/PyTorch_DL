# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import seaborn as sns
from sklearn.metrics import precision_recall_curve

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu'   )
RANDOM_SEED = 42
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
print(DEVICE)
# Out:
# cuda

# %%
import os
DATA_DIR = '../data/processed/'

X_train = np.load(DATA_DIR + 'X_train_scaled_cancer.npy')
X_val = np.load(DATA_DIR + 'X_val_scaled_cancer.npy')
X_test = np.load(DATA_DIR + 'X_test_scaled_cancer.npy')

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(type(X_train))
# Out:
# (341, 30)
# (114, 30)
# (114, 30)
# <class 'numpy.ndarray'>

# %%
y_train = np.load(DATA_DIR + 'y_train_cancer.npy')
y_val = np.load(DATA_DIR + 'y_val_cancer.npy')
y_test = np.load(DATA_DIR + 'y_test_cancer.npy')

print(y_train.shape)
print(type(y_train))
# Out:
# (341,)
# <class 'numpy.ndarray'>

# %%
X_train_t = torch.tensor(X_train, dtype = torch.float32)
X_test_t = torch.tensor(X_test, dtype = torch.float32)
X_val_t = torch.tensor(X_val, dtype = torch.float32)

print(X_train_t.shape)
print(X_val_t.shape)
print(X_test_t.shape)
print(type(X_train_t))
# Out:
# torch.Size([341, 30])
# torch.Size([114, 30])
# torch.Size([114, 30])
# <class 'torch.Tensor'>

# %%
y_train_t = torch.tensor(y_train, dtype = torch.float32).unsqueeze(1)
y_test_t = torch.tensor(y_test, dtype = torch.float32).unsqueeze(1)
y_val_t = torch.tensor(y_val, dtype = torch.float32).unsqueeze(1)

print(y_train_t.shape)
print(type(y_train_t))
# Out:
# torch.Size([341, 1])
# <class 'torch.Tensor'>

# %%
class LogisticDataset(Dataset):
    def __init__(self, X,y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx] , self.y[idx]

# %%
training_dataset = LogisticDataset(X_train_t, y_train_t)
validation_dataset = LogisticDataset(X_val_t, y_val_t)
testing_dataset = LogisticDataset(X_test_t, y_test_t)

# %%
print(training_dataset[0])
# Out:
# (tensor([-1.5895, -1.3608, -1.5522, -1.2792,  0.5916, -0.4925, -0.7697, -0.8602,
#         -0.4526,  1.1800, -1.1683, -0.9623, -1.0053, -0.9199,  0.2719, -0.4111,
#         -0.4167, -0.6625, -0.5490,  0.0278, -1.4072, -1.1442, -1.3089, -1.0886,
#          1.3998, -0.1951, -0.4599, -0.4268,  0.0891,  1.0829]), tensor([1.]))

# %%
len(training_dataset)
# Out:
# 341

# %%
train_loader = DataLoader(training_dataset, batch_size= 32, shuffle = True, num_workers= 0)
val_loader = DataLoader(validation_dataset, batch_size= 32, shuffle = False, num_workers= 0)
test_loader = DataLoader(testing_dataset, batch_size= 32, shuffle = False, num_workers= 0)

# %%
class LogisticRegression(nn.Module):
    def __init__(self, D_in, D_out = 1):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(D_in, D_out)

    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
D_in = X_train_t.shape[-1]

# %%
D_in
# Out:
# 30

# %%
classifer_model = LogisticRegression(D_in)

# %%
classifer_model = classifer_model.to(DEVICE)
print(classifer_model)
# Out:
# LogisticRegression(
#   (linear): Linear(in_features=30, out_features=1, bias=True)
# )

# %%
classifer_model.linear.weight.data
# Out:
# tensor([[ 0.1396,  0.1515, -0.0428,  0.1677, -0.0400,  0.0368, -0.0889,  0.1072,
#           0.1609, -0.1339,  0.1587,  0.0342,  0.1349,  0.0247,  0.0880, -0.0258,
#           0.1407,  0.0270, -0.0852,  0.0465, -0.0841, -0.0214, -0.0742,  0.1211,
#          -0.1441, -0.0842, -0.0516, -0.1098,  0.0172, -0.1803]],
#        device='cuda:0')

# %%
criterion = nn.BCELoss()
LEARNING_RATE = 1e-3
optimizer = torch.optim.Adam(classifer_model.parameters(), lr = LEARNING_RATE)

# %%
N_EPOCHS = 50
train_losses= []
val_losses = []

for epoch in range(N_EPOCHS):
    classifer_model.train()
    epoch_train_loss = 0.0

    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(DEVICE)
        y_batch = y_batch.to(DEVICE)

        optimizer.zero_grad()
        predictions = classifer_model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()

    avg_train_loss = epoch_train_loss/len(train_loader)
    train_losses.append(avg_train_loss)

    classifer_model.eval()
    epoch_val_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)

            val_predictions = classifer_model(X_batch)
            val_loss = criterion(val_predictions, y_batch)
            predicted_labels = (val_predictions >= 0.5).float()
            correct += (predicted_labels == y_batch).sum().item()
            total += y_batch.size(0)
            epoch_val_loss += val_loss.item()

    accuracy = correct / total

    avg_val_loss = epoch_val_loss/len(val_loader)
    val_losses.append(avg_val_loss)
    
    print(f"for {epoch+1}/{N_EPOCHS} epoch: the training loss: {avg_train_loss:.4f} and validation loss: {avg_val_loss:.4f} and accuracy : {accuracy:.4f}")
# Out:
# for 1/50 epoch: the training loss: 0.8052 and validation loss: 0.7635 and accuracy : 0.4912
# for 2/50 epoch: the training loss: 0.7261 and validation loss: 0.6951 and accuracy : 0.5526
# for 3/50 epoch: the training loss: 0.6590 and validation loss: 0.6346 and accuracy : 0.6053
# for 4/50 epoch: the training loss: 0.6005 and validation loss: 0.5825 and accuracy : 0.7105
# for 5/50 epoch: the training loss: 0.5492 and validation loss: 0.5378 and accuracy : 0.8070
# for 6/50 epoch: the training loss: 0.5084 and validation loss: 0.4989 and accuracy : 0.8333
# for 7/50 epoch: the training loss: 0.4732 and validation loss: 0.4655 and accuracy : 0.8684
# for 8/50 epoch: the training loss: 0.4394 and validation loss: 0.4374 and accuracy : 0.8772
# for 9/50 epoch: the training loss: 0.4134 and validation loss: 0.4127 and accuracy : 0.8860
# for 10/50 epoch: the training loss: 0.3893 and validation loss: 0.3913 and accuracy : 0.9035
# for 11/50 epoch: the training loss: 0.3689 and validation loss: 0.3720 and accuracy : 0.9035
# for 12/50 epoch: the training loss: 0.3519 and validation loss: 0.3548 and accuracy : 0.9123
# for 13/50 epoch: the training loss: 0.3360 and validation loss: 0.3393 and accuracy : 0.9211
# for 14/50 epoch: the training loss: 0.3200 and validation loss: 0.3251 and accuracy : 0.9211
# for 15/50 epoch: the training loss: 0.3075 and validation loss: 0.3122 and accuracy : 0.9298
# for 16/50 epoch: the training loss: 0.2993 and validation loss: 0.3004 and accuracy : 0.9474
# for 17/50 epoch: the training loss: 0.2868 and validation loss: 0.2897 and accuracy : 0.9474
# for 18/50 epoch: the training loss: 0.2782 and validation loss: 0.2800 and accuracy : 0.9474
# for 19/50 epoch: the training loss: 0.2671 and validation loss: 0.2710 and accuracy : 0.9474
# for 20/50 epoch: the training loss: 0.2582 and validation loss: 0.2625 and accuracy : 0.9474
# for 21/50 epoch: the training loss: 0.2520 and validation loss: 0.2544 and accuracy : 0.9474
# for 22/50 epoch: the training loss: 0.2462 and validation loss: 0.2469 and accuracy : 0.9474
# for 23/50 epoch: the training loss: 0.2389 and validation loss: 0.2404 and accuracy : 0.9474
# for 24/50 epoch: the training loss: 0.2311 and validation loss: 0.2339 and accuracy : 0.9474
# for 25/50 epoch: the training loss: 0.2273 and validation loss: 0.2276 and accuracy : 0.9474
# for 26/50 epoch: the training loss: 0.2200 and validation loss: 0.2219 and accuracy : 0.9474
# for 27/50 epoch: the training loss: 0.2154 and validation loss: 0.2165 and accuracy : 0.9474
# for 28/50 epoch: the training loss: 0.2099 and validation loss: 0.2113 and accuracy : 0.9474
# for 29/50 epoch: the training loss: 0.2056 and validation loss: 0.2065 and accuracy : 0.9474
# for 30/50 epoch: the training loss: 0.2028 and validation loss: 0.2018 and accuracy : 0.9561
# for 31/50 epoch: the training loss: 0.2021 and validation loss: 0.1975 and accuracy : 0.9561
# for 32/50 epoch: the training loss: 0.1956 and validation loss: 0.1934 and accuracy : 0.9561
# for 33/50 epoch: the training loss: 0.1925 and validation loss: 0.1894 and accuracy : 0.9561
# for 34/50 epoch: the training loss: 0.1858 and validation loss: 0.1856 and accuracy : 0.9561
# for 35/50 epoch: the training loss: 0.1845 and validation loss: 0.1818 and accuracy : 0.9649
# for 36/50 epoch: the training loss: 0.1803 and validation loss: 0.1785 and accuracy : 0.9737
# for 37/50 epoch: the training loss: 0.1783 and validation loss: 0.1751 and accuracy : 0.9737
# for 38/50 epoch: the training loss: 0.1750 and validation loss: 0.1719 and accuracy : 0.9737
# for 39/50 epoch: the training loss: 0.1752 and validation loss: 0.1690 and accuracy : 0.9737
# for 40/50 epoch: the training loss: 0.1707 and validation loss: 0.1660 and accuracy : 0.9737
# for 41/50 epoch: the training loss: 0.1721 and validation loss: 0.1633 and accuracy : 0.9737
# for 42/50 epoch: the training loss: 0.1664 and validation loss: 0.1605 and accuracy : 0.9737
# for 43/50 epoch: the training loss: 0.1665 and validation loss: 0.1579 and accuracy : 0.9737
# for 44/50 epoch: the training loss: 0.1647 and validation loss: 0.1555 and accuracy : 0.9737
# for 45/50 epoch: the training loss: 0.1610 and validation loss: 0.1531 and accuracy : 0.9737
# for 46/50 epoch: the training loss: 0.1618 and validation loss: 0.1508 and accuracy : 0.9737
# for 47/50 epoch: the training loss: 0.1558 and validation loss: 0.1486 and accuracy : 0.9737
# for 48/50 epoch: the training loss: 0.1554 and validation loss: 0.1465 and accuracy : 0.9737
# for 49/50 epoch: the training loss: 0.1519 and validation loss: 0.1443 and accuracy : 0.9737
# for 50/50 epoch: the training loss: 0.1495 and validation loss: 0.1423 and accuracy : 0.9737

# %%
plt.figure(figsize=(8,5),dpi = 150)
epochs_range = range(1, N_EPOCHS + 1)
plt.plot(epochs_range, train_losses, linewidth = 2, color = 'royalblue', label = 'train loss')
plt.plot(epochs_range, val_losses, linewidth = 2, color = 'coral', ls='--', label = 'Val Loss')
plt.xlabel('Epochs')
plt.ylabel('BCE Loss')
plt.legend(loc = 1)
plt.grid()
plt.tight_layout()
plt.savefig('test_figue.png', dpi = 200)

# %%
all_pred = []
true_pred = []
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch = x_batch.to(DEVICE)
        y_batch = y_batch.to(DEVICE)

        predictions = classifer_model(x_batch)
        pred_label = ( predictions >= 0.7 ).float()
        all_pred.append(np.array(pred_label.cpu().flatten()))
        true_pred.append(y_batch.cpu().numpy().flatten())
    
    y_hat = np.concatenate(all_pred)
    gnd_truth = np.concatenate(true_pred)
    fpr, tpr, thresholds = roc_curve(gnd_truth, y_hat)
    auc = roc_auc_score(gnd_truth, y_hat)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, color='royalblue', linewidth=2, label=f'AUC = {auc:.3f}')
    plt.plot([0, 1], [0, 1], 'k--', linewidth=1, label='Random classifier')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate (Recall)')
    plt.title('ROC Curve')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.savefig('roc_curve.png', dpi=150)
    plt.show()
    precision, recall, thresholds = precision_recall_curve(gnd_truth, y_hat)
    plt.figure(figsize=(6, 5))
    plt.plot(recall, precision, color='coral', linewidth=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.grid()
    plt.tight_layout()
    plt.savefig('precision_recall_curve.png', dpi=150)
    plt.show()

    malignant_probs = y_hat[gnd_truth == 0]
    benign_probs = y_hat[gnd_truth == 1]
    
    plt.figure(figsize=(7, 5))
    plt.hist(malignant_probs, bins=20, alpha=0.6, color='red', label='Actual Malignant (0)')
    plt.hist(benign_probs, bins=20, alpha=0.6, color='green', label='Actual Benign (1)')
    plt.axvline(x=0.5, color='black', linestyle='--', linewidth=1.5, label='Threshold = 0.5')
    plt.xlabel('Predicted Probability (Benign)')
    plt.ylabel('Count')
    plt.title('Prediction Probability Distribution by True Class')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.savefig('prob_distribution.png', dpi=150)
    plt.show()
    conf_matrix = confusion_matrix(gnd_truth,y_hat)
    print(classification_report( gnd_truth, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.98      0.91        43
#          1.0       0.98      0.90      0.94        71
#
#     accuracy                           0.93       114
#    macro avg       0.92      0.94      0.93       114
# weighted avg       0.94      0.93      0.93       114

# %%
print(conf_matrix)
# Out:
# [[42  1]
#  [ 7 64]]

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Malignant', 'Benign'],
            yticklabels=['Malignant', 'Benign'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150)
