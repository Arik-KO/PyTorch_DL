# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu'   )

# %%
print(DEVICE)
# Out:
# cuda

# %%
import os
DATA_DIR = '../data/processed/'

X_train = np.load(DATA_DIR + 'X_train_scaled_cancer.npy')
X_val = np.load(DATA_DIR + 'X_val_scaled_cancer.npy')
X_test = np.load(DATA_DIR + 'X_test_scaled_cancer.npy')

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(type(X_train))
# Out:
# (341, 30)
# (114, 30)
# (114, 30)
# <class 'numpy.ndarray'>

# %%
y_train = np.load(DATA_DIR + 'y_train_cancer.npy')
y_val = np.load(DATA_DIR + 'y_val_cancer.npy')
y_test = np.load(DATA_DIR + 'y_test_cancer.npy')

print(y_train.shape)
print(type(y_train))
# Out:
# (341,)
# <class 'numpy.ndarray'>

# %%
X_train_t = torch.tensor(X_train, dtype = torch.float32)
X_test_t = torch.tensor(X_test, dtype = torch.float32)
X_val_t = torch.tensor(X_val, dtype = torch.float32)

print(X_train_t.shape)
print(X_val_t.shape)
print(X_test_t.shape)
print(type(X_train_t))
# Out:
# torch.Size([341, 30])
# torch.Size([114, 30])
# torch.Size([114, 30])
# <class 'torch.Tensor'>

# %%
y_train_t = torch.tensor(y_train, dtype = torch.float32).unsqueeze(1)
y_test_t = torch.tensor(y_test, dtype = torch.float32).unsqueeze(1)
y_val_t = torch.tensor(y_val, dtype = torch.float32).unsqueeze(1)

print(y_train_t.shape)
print(type(y_train_t))
# Out:
# torch.Size([341, 1])
# <class 'torch.Tensor'>

# %%
class LogisticDataset(Dataset):
    def __init__(self, X,y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx] , self.y[idx]

# %%
training_dataset = LogisticDataset(X_train_t, y_train_t)
validation_dataset = LogisticDataset(X_val_t, y_val_t)
testing_dataset = LogisticDataset(X_test_t, y_test_t)

# %%
print(training_dataset[0])
# Out:
# (tensor([-1.5895, -1.3608, -1.5522, -1.2792,  0.5916, -0.4925, -0.7697, -0.8602,
#         -0.4526,  1.1800, -1.1683, -0.9623, -1.0053, -0.9199,  0.2719, -0.4111,
#         -0.4167, -0.6625, -0.5490,  0.0278, -1.4072, -1.1442, -1.3089, -1.0886,
#          1.3998, -0.1951, -0.4599, -0.4268,  0.0891,  1.0829]), tensor([1.]))

# %%
len(training_dataset)
# Out:
# 341

# %%
train_loader = DataLoader(training_dataset, batch_size= 32, shuffle = True, num_workers= 0)
val_loader = DataLoader(validation_dataset, batch_size= 32, shuffle = True, num_workers= 0)
test_loader = DataLoader(testing_dataset, batch_size= 32, shuffle = True, num_workers= 0)

# %%
class LogisticRegression(nn.Module):
    def __init__(self, D_in, D_out = 1):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(D_in, D_out)

    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
D_in = X_train_t.shape[-1]

# %%
D_in
# Out:
# 30

# %%
classifer_model = LogisticRegression(D_in)

# %%
classifer_model = classifer_model.to(DEVICE)
print(classifer_model)
# Out:
# LogisticRegression(
#   (linear): Linear(in_features=30, out_features=1, bias=True)
# )

# %%
classifer_model.linear.weight.data
# Out:
# tensor([[-0.0812,  0.0592, -0.0427,  0.1628,  0.0722,  0.0299, -0.0947, -0.0640,
#          -0.0347,  0.1696, -0.1334,  0.1206,  0.1071,  0.1777, -0.0321, -0.1412,
#          -0.0977,  0.0630,  0.1085,  0.0593, -0.0774,  0.1208, -0.0342,  0.1597,
#          -0.1191,  0.1269,  0.0069,  0.1689,  0.0807, -0.1116]],
#        device='cuda:0')

# %%
criterion = nn.BCELoss()
LEARNING_RATE = 1e-3
optimizer = torch.optim.Adam(classifer_model.parameters(), lr = LEARNING_RATE)

# %%
N_EPOCHS = 50
train_losses= []
val_losses = []

for epoch in range(N_EPOCHS):
    classifer_model.train()
    epoch_train_loss = 0.0

    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(DEVICE)
        y_batch = y_batch.to(DEVICE)

        optimizer.zero_grad()
        predictions = classifer_model(X_batch)
        loss = criterion(predictions, y_batch)
        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()

    avg_train_loss = epoch_train_loss/len(train_loader)
    train_losses.append(avg_train_loss)

    classifer_model.eval()
    epoch_val_loss = 0.0

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)

            val_predictions = classifer_model(X_batch)
            val_loss = criterion(val_predictions, y_batch)
            epoch_val_loss += val_loss.item()

    avg_val_loss = epoch_val_loss/len(val_loader)
    val_losses.append(avg_val_loss)

    print(f"for {epoch+1}/{N_EPOCHS} epoch: the training loss: {avg_train_loss:.4f} and validation loss: {avg_val_loss:.4f}")
# Out:
# for 0/50 epoch: the training loss: 0.7918 and validation loss: 0.7599
# for 1/50 epoch: the training loss: 0.7108 and validation loss: 0.6782
# for 2/50 epoch: the training loss: 0.6423 and validation loss: 0.6283
# for 3/50 epoch: the training loss: 0.5842 and validation loss: 0.5694
# for 4/50 epoch: the training loss: 0.5347 and validation loss: 0.5143
# for 5/50 epoch: the training loss: 0.4920 and validation loss: 0.4789
# for 6/50 epoch: the training loss: 0.4558 and validation loss: 0.4450
# for 7/50 epoch: the training loss: 0.4239 and validation loss: 0.4163
# for 8/50 epoch: the training loss: 0.4013 and validation loss: 0.3946
# for 9/50 epoch: the training loss: 0.3794 and validation loss: 0.3763
# for 10/50 epoch: the training loss: 0.3615 and validation loss: 0.3538
# for 11/50 epoch: the training loss: 0.3444 and validation loss: 0.3413
# for 12/50 epoch: the training loss: 0.3282 and validation loss: 0.3195
# for 13/50 epoch: the training loss: 0.3151 and validation loss: 0.3096
# for 14/50 epoch: the training loss: 0.3029 and validation loss: 0.2975
# for 15/50 epoch: the training loss: 0.2898 and validation loss: 0.2844
# for 16/50 epoch: the training loss: 0.2811 and validation loss: 0.2742
# for 17/50 epoch: the training loss: 0.2733 and validation loss: 0.2597
# for 18/50 epoch: the training loss: 0.2636 and validation loss: 0.2575
# for 19/50 epoch: the training loss: 0.2568 and validation loss: 0.2488
# for 20/50 epoch: the training loss: 0.2503 and validation loss: 0.2386
# for 21/50 epoch: the training loss: 0.2433 and validation loss: 0.2390
# for 22/50 epoch: the training loss: 0.2353 and validation loss: 0.2334
# for 23/50 epoch: the training loss: 0.2290 and validation loss: 0.2226
# for 24/50 epoch: the training loss: 0.2258 and validation loss: 0.2210
# for 25/50 epoch: the training loss: 0.2205 and validation loss: 0.2101
# for 26/50 epoch: the training loss: 0.2167 and validation loss: 0.2119
# for 27/50 epoch: the training loss: 0.2092 and validation loss: 0.1975
# for 28/50 epoch: the training loss: 0.2062 and validation loss: 0.2008
# for 29/50 epoch: the training loss: 0.2018 and validation loss: 0.1941
# for 30/50 epoch: the training loss: 0.1975 and validation loss: 0.1900
# for 31/50 epoch: the training loss: 0.1933 and validation loss: 0.1853
# for 32/50 epoch: the training loss: 0.1961 and validation loss: 0.1816
# for 33/50 epoch: the training loss: 0.1853 and validation loss: 0.1769
# for 34/50 epoch: the training loss: 0.1861 and validation loss: 0.1834
# for 35/50 epoch: the training loss: 0.1832 and validation loss: 0.1662
# for 36/50 epoch: the training loss: 0.1765 and validation loss: 0.1675
# for 37/50 epoch: the training loss: 0.1738 and validation loss: 0.1645
# for 38/50 epoch: the training loss: 0.1721 and validation loss: 0.1564
# for 39/50 epoch: the training loss: 0.1692 and validation loss: 0.1607
# for 40/50 epoch: the training loss: 0.1702 and validation loss: 0.1614
# for 41/50 epoch: the training loss: 0.1668 and validation loss: 0.1623
# for 42/50 epoch: the training loss: 0.1638 and validation loss: 0.1462
# for 43/50 epoch: the training loss: 0.1653 and validation loss: 0.1527
# for 44/50 epoch: the training loss: 0.1595 and validation loss: 0.1493
# for 45/50 epoch: the training loss: 0.1574 and validation loss: 0.1452
# for 46/50 epoch: the training loss: 0.1534 and validation loss: 0.1384
# for 47/50 epoch: the training loss: 0.1521 and validation loss: 0.1466
# for 48/50 epoch: the training loss: 0.1505 and validation loss: 0.1353
# for 49/50 epoch: the training loss: 0.1490 and validation loss: 0.1416

# %%
plt.figure(figsize=(8,5),dpi = 150)
epochs_range = range(1, N_EPOCHS + 1)
plt.plot(epochs_range, train_losses, linewidth = 2, color = 'royalblue', label = 'train loss')
plt.plot(epochs_range, train_losses, linewidth = 2, color = 'coral', ls='--', label = 'Val Loss')
plt.xlabel('Epochs')
plt.ylabel('BCE Loss')
plt.legend(loc = 1)
plt.grid()
plt.tight_layout()
plt.savefig('test_figue.png', dpi = 200)
