# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %%
len(data.data)

# %%
data.target

# %%
type(data)

# %%
data

# %%
type(data.data)

# %%
type(data.target)

# %%
import pandas as pd
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# %%
df

# %%
df.info()

# %%
df.isnull().sum()

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X.shape

# %%
y.shape

# %%
type(X)

# %%
type(y)

# %%
import numpy as np

# %%
import os
os.makedirs('../data/raw', exist_ok= True)

# %%
np.save('../data/raw/X_raw.npy', X)

# %%
np.save('../data/raw/y_raw.npy', y)

# %%
X_check = np.load('../data/raw/X_raw.npy')

# %%
X_check.shape

# %%
X_check[0:4]
